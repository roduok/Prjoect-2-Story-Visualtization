# %%
import sqlalchemy
from sqlalchemy import Column, Float, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import create_engine, func, inspect, Date
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import sem

# %%
Base = declarative_base()
class Businesspattern(Base):
    __tablename__ = "businesspattern"
    
    id = Column(Integer, primary_key=True)
    ESTAB = Column(Integer)
    NAICS2012 = Column(String)
    ZIPCODE = Column(String) 
    NAICS2012_TTL = Column(String)


engine = create_engine("sqlite:///usBusinesses.sqlite")
Base.metadata.create_all(engine)

# %%
def populate_table (engine, table, csvfile):
    conn = engine.connect()
    
    
    
    df_insert = pd.read_csv(csvfile)
    
    data = df_insert.to_dict(orient='records')
    conn.execute(table.insert(), data)
populate_table(engine, Businesspattern.__table__,'census_data.csv')

# %%
engine.execute("SELECT * FROM businesspattern").fetchall()
# Out:
# [(1, 1, '11', '1005', 'Agriculture, Forestry, Fishing and Hunting'),
#  (2, 1, '11', '1007', 'Agriculture, Forestry, Fishing and Hunting'),
#  (3, 1, '11', '1010', 'Agriculture, Forestry, Fishing and Hunting'),
#  (4, 1, '11', '1030', 'Agriculture, Forestry, Fishing and Hunting'),
#  (5, 1, '11', '1033', 'Agriculture, Forestry, Fishing and Hunting'),
#  (6, 1, '11', '1034', 'Agriculture, Forestry, Fishing and Hunting'),
#  (7, 1, '11', '1036', 'Agriculture, Forestry, Fishing and Hunting'),
#  (8, 1, '11', '1038', 'Agriculture, Forestry, Fishing and Hunting'),
#  (9, 1, '11', '1057', 'Agriculture, Forestry, Fishing and Hunting'),
#  (10, 1, '11', '1059', 'Agriculture, Forestry, Fishing and Hunting'),
#  (11, 1, '11', '1062', 'Agriculture, Forestry, Fishing and Hunting'),
#  (12, 1, '11', '1069', 'Agriculture, Forestry, Fishing and Hunting'),
#  (13, 1, '11', '1071', 'Agriculture, Forestry, Fishing and Hunting'),
#  (14, 3, '11', '1077', 'Agriculture, Forestry, Fishing and Hunting'),
# ...
