# %%
# Dependencies
from ratelimit import rate_limited
import requests as req
import json
import pandas as pd

# URL for GET requests to retrieve vehicle data
censuslink = "https://api.census.gov/data/2015/zbp?get=EMP&for=ZIPCODE:*&for=NAICS2012:*&key=d78cecd59efe40449efbea033ae5a136a0226ad0"

@rate_limited(5)
def call_api(url):
    response = req.get(url).json()
    return response
        
print(call_api(censuslink))
# Out:
# [['EMP', 'zipcode'], ['0', '00501'], ['9641', '01001'], ['18764', '01002'], ['267', '01003'], ['165', '01004'], ['926', '01005'], ['1864', '01007'], ['220', '01008'], ['142', '01009'], ['271', '01010'], ['32', '01011'], ['45', '01012'], ['4331', '01013'], ['0', '01014'], ['8768', '01020'], ['196', '01021'], ['1931', '01022'], ['70', '01026'], ['3892', '01027'], ['7114', '01028'], ['264', '01029'], ['1206', '01030'], ['59', '01031'], ['100', '01032'], ['731', '01033'], ['131', '01034'], ['5061', '01035'], ['849', '01036'], ['267', '01037'], ['1358', '01038'], ['222', '01039'], ['16968', '01040'], ['942', '01041'], ['236', '01050'], ['1645', '01053'], ['122', '01054'], ['4179', '01056'], ['753', '01057'], ['107', '01059'], ['11883', '01060'], ['111', '01061'], ['1797', '01062'], ['0', '01063'], ['0', '01066'], ['62', '01068'], ['3349', '01069'], ['20', '01070'], ['80', '01071'], ['55', '01072'], ['1017', '01073'], ['69', '01074'], ['4791', '01075'], ['1937', '01077'], ['72', '01079'], 
# ...

# %%
# Dependencies
from ratelimit import rate_limited
import requests as req
import json
import pandas as pd

# URL for GET requests to retrieve vehicle data
censuslink2 = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=23&key=d78cecd59efe40449efbea033ae5a136a0226ad0"
#censuslink3 = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=52&key=d78cecd59efe40449efbea033ae5a136a0226ad0"
#censuslink4 = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=54&key=d78cecd59efe40449efbea033ae5a136a0226ad0"
#censuslink5 = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=54&key=d78cecd59efe40449efbea033ae5a136a0226ad0"

@rate_limited(5)
def call_api(url):
    response = req.get(url).text
    return response

census_2 = call_api(censuslink2)
#census_3 = call_api(censuslink3)
#census_4 = call_api(censuslink4)
#census_5 = call_api(censuslink5)

# %%
census_df2 = pd.DataFrame(census_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-c0e00e69de8f> in <module>()
# ----> 1 census_df2 = pd.DataFrame(census_2)
#
# /Users/Cyrus/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     402                                          dtype=values.dtype, copy=False)
#     403             else:
# --> 404                 raise ValueError('DataFrame constructor not properly called!')
#     405
#     406         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
census_df2 = pd.DataFrame(census_2)
census_df2.columns = empl_df.iloc[0]
census_df2.reindex(empl_df.index.drop(0))

census_df3 = pd.DataFrame(census_3)
census_df3.columns = empl_df.iloc[0]
census_df3.reindex(empl_df.index.drop(0))

census_df4 = pd.DataFrame(census_4)
census_df4.columns = empl_df.iloc[0]
census_df4.reindex(empl_df.index.drop(0))

census_df5 = pd.DataFrame(census_5)
census_df5.columns = empl_df.iloc[0]
census_df5.reindex(empl_df.index.drop(0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-e50f15b5d4fd> in <module>()
# ----> 1 census_df2 = pd.DataFrame(census_2)
#       2 census_df2.columns = empl_df.iloc[0]
#       3 census_df2.reindex(empl_df.index.drop(0))
#       4
#       5 census_df3 = pd.DataFrame(census_3)
#
# /Users/Cyrus/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     402                                          dtype=values.dtype, copy=False)
#     403             else:
# --> 404                 raise ValueError('DataFrame constructor not properly called!')
#     405
#     406         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
census_df2.head()
census_df3.head()
census_df4.head()
census_df5.head()

# %%
# Dependencies
from ratelimit import rate_limited
import requests as req
import json
import pandas as pd

# URL for GET requests to retrieve vehicle data
censuslink3 = "https://api.census.gov/data/2015/zbp?get=EMP&for=ZIPCODE:*&NAICS2012=52&key=d78cecd59efe40449efbea033ae5a136a0226ad0"

@rate_limited(5)
def call_api(url):
    response = req.get(url).json()
    return response
        
census_3 = call_api(censuslink3)

# %%
census_df3 = pd.DataFrame(census_3)
census_df3.head()
# Out:
#      0          1        2
# 0  EMP  NAICS2012  zipcode
# 1    0         52    01001
# 2    0         52    01002
# 3    0         52    01003
# 4    0         52    01004

# %%
# Dependencies
from ratelimit import rate_limited
import requests as req
import json
import pandas as pd

# URL for GET requests to retrieve vehicle data
censuslink4 = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=54&key=d78cecd59efe40449efbea033ae5a136a0226ad0"

@rate_limited(5)
def call_api(url):
    response = req.get(url).json()
    return response
        
census_4 = call_api(censuslink4)

# %%
census_df4 = pd.DataFrame(census_4)
census_df4
# Out:
#            0          1        2
# 0      ESTAB  NAICS2012  zipcode
# 1         42         54    01001
# 2         89         54    01002
# 3          1         54    01003
# 4          1         54    01004
# 5         12         54    01005
# 6         21         54    01007
# 7          2         54    01008
# 8          1         54    01009
# 9          7         54    01010
# 10         1         54    01012
# 11        15         54    01013
# 12        22         54    01020
# 13         4         54    01022
# 14         2         54    01026
# 15        38         54    01027
# 16        48         54    01028
# 17         1         54    01029
# 18        17         54    01030
# 19         1         54    01032
# 20         7         54    01033
# 21         3         54    01034
# 22        29         54    01035
# 23         6         54    01036
# 24         2         54    01037
# 25         2         54    01038
# 26         2         54    01039
# ...

# %%
empl_df.columns = empl_df.iloc[0]
empl_df.reindex(empl_df.index.drop(0))
