# %%
# Dependencies
from ratelimit import rate_limited
import requests as req
import json

# URL for GET requests to retrieve vehicle data


# url = "https://api.census.gov/data/2015/zbp?get=EMP,GEO_TTL&for=zipcode:20002&key=d78cecd59efe40449efbea033ae5a136a0226ad0"

# url="https://api.census.gov/data/2015/cbp?get=ESTAB,LFO,NAICS2012_TTL,GEO_TTL&for=state:07&&key=d78cecd59efe40449efbea033ae5a136a0226ad"

# url=" api.census.gov/data/2015/zbp?get=ESTAB,EMPSZES&for=zipcode:*&NAICS2012*=72
  
    
# url = "https://api.census.gov/data/2015/zbp?get=EMP,PAYANN,ESTAB,NAICS2012_TTL&for=zipcode:*&for=NAICS2012:*key=d78cecd59efe40449efbea033ae5a136a0226ad0"
  
url = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=51&key=d78cecd59efe40449efbea033ae5a136a0226ad0"    
response = req.get(url).json()

@rate_limited(5)
def call_api(self, url):
    response = req.get(url).json()

    if response.status_code != 200:
        raise ApiError('Cannot call API: {}'.format(response.status_code))

    return response
print(response)
# Out:
# [['ESTAB', 'NAICS2012', 'zipcode'], ['3', '51', '01001'], ['13', '51', '01002'], ['3', '51', '01003'], ['2', '51', '01004'], ['2', '51', '01007'], ['3', '51', '01013'], ['9', '51', '01020'], ['6', '51', '01027'], ['6', '51', '01028'], ['1', '51', '01033'], ['1', '51', '01034'], ['6', '51', '01035'], ['1', '51', '01036'], ['1', '51', '01037'], ['1', '51', '01038'], ['1', '51', '01039'], ['8', '51', '01040'], ['1', '51', '01053'], ['4', '51', '01056'], ['2', '51', '01057'], ['28', '51', '01060'], ['1', '51', '01061'], ['3', '51', '01062'], ['3', '51', '01066'], ['4', '51', '01069'], ['2', '51', '01073'], ['3', '51', '01075'], ['1', '51', '01082'], ['8', '51', '01085'], ['8', '51', '01089'], ['1', '51', '01090'], ['1', '51', '01092'], ['1', '51', '01095'], ['1', '51', '01096'], ['1', '51', '01098'], ['1', '51', '01101'], ['16', '51', '01103'], ['6', '51', '01104'], ['20', '51', '01105'], ['5', '51', '01106'], ['5', '51', '01107'], ['1', '51', '01108'], ['4', '51', '01109'], ['3', '51', 
# ...

# %%
with open('data.txt', 'w') as outfile:
     json.dump(response, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

# %%
import pandas as pd

empl_df_51= pd.read_json('data.txt', orient='records')
pd.read_json('data.txt', orient='records')
empl_df_51.columns = empl_df_51.iloc[0]
empl_df_51.reindex(empl_df_51.index.drop(0))

# empl_df["PAYANN"] = (empl_df["PAYANN"]).astype(int)
# empl_df["EMP"] = (empl_df["EMP"]).astype(int)
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1         3        51   01001
# 2        13        51   01002
# 3         3        51   01003
# 4         2        51   01004
# 5         2        51   01007
# 6         3        51   01013
# 7         9        51   01020
# 8         6        51   01027
# 9         6        51   01028
# 10        1        51   01033
# 11        1        51   01034
# 12        6        51   01035
# 13        1        51   01036
# 14        1        51   01037
# 15        1        51   01038
# 16        1        51   01039
# 17        8        51   01040
# 18        1        51   01053
# 19        4        51   01056
# 20        2        51   01057
# 21       28        51   01060
# 22        1        51   01061
# 23        3        51   01062
# 24        3        51   01066
# 25        4        51   01069
# 26        2        51   01073
# 27        3        51   01075
# 28        1        51   01082
# 29        8        51   01085
# 30        8        51   01089
# ...

# %%
url = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=11&key=d78cecd59efe40449efbea033ae5a136a0226ad0"    
response_11 = req.get(url).json()

@rate_limited(5)
def call_api(self, url):
    response_11 = req.get(url).json()

    if response_11.status_code != 200:
        raise ApiError('Cannot call API: {}'.format(response_11.status_code))

    return response_11
print(response_11)
# Out:
# [['ESTAB', 'NAICS2012', 'zipcode'], ['1', '11', '01005'], ['1', '11', '01007'], ['1', '11', '01010'], ['1', '11', '01030'], ['1', '11', '01033'], ['1', '11', '01034'], ['1', '11', '01036'], ['1', '11', '01038'], ['1', '11', '01057'], ['1', '11', '01059'], ['1', '11', '01062'], ['1', '11', '01069'], ['1', '11', '01071'], ['3', '11', '01077'], ['1', '11', '01081'], ['1', '11', '01082'], ['1', '11', '01095'], ['1', '11', '01201'], ['1', '11', '01220'], ['1', '11', '01230'], ['1', '11', '01237'], ['1', '11', '01243'], ['1', '11', '01254'], ['1', '11', '01255'], ['2', '11', '01262'], ['1', '11', '01267'], ['1', '11', '01355'], ['2', '11', '01360'], ['1', '11', '01364'], ['1', '11', '01366'], ['1', '11', '01431'], ['2', '11', '01450'], ['4', '11', '01451'], ['2', '11', '01452'], ['1', '11', '01460'], ['1', '11', '01464'], ['5', '11', '01473'], ['2', '11', '01475'], ['2', '11', '01501'], ['2', '11', '01503'], ['2', '11', '01519'], ['1', '11', '01521'], ['1', '11', '01534'], ['1', '11', '015
# ...

# %%
with open('data11.txt', 'w') as outfile:
     json.dump(response, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

import pandas as pd

empl_df_11= pd.read_json('data11.txt', orient='records')
pd.read_json('data11.txt', orient='records')
empl_df_11.columns = empl_df_11.iloc[0]
empl_df_11.reindex(empl_df_11.index.drop(0))
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1         1        11   01005
# 2         1        11   01007
# 3         1        11   01010
# 4         1        11   01030
# 5         1        11   01033
# 6         1        11   01034
# 7         1        11   01036
# 8         1        11   01038
# 9         1        11   01057
# 10        1        11   01059
# 11        1        11   01062
# 12        1        11   01069
# 13        1        11   01071
# 14        3        11   01077
# 15        1        11   01081
# 16        1        11   01082
# 17        1        11   01095
# 18        1        11   01201
# 19        1        11   01220
# 20        1        11   01230
# 21        1        11   01237
# 22        1        11   01243
# 23        1        11   01254
# 24        1        11   01255
# 25        2        11   01262
# 26        1        11   01267
# 27        1        11   01355
# 28        2        11   01360
# 29        1        11   01364
# 30        1        11   01366
# ...

# %%
url = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=52&key=d78cecd59efe40449efbea033ae5a136a0226ad0"    
response_52 = req.get(url).json()

@rate_limited(5)
def call_api(self, url):
    response_52 = req.get(url).json()

    if response_52.status_code != 200:
        raise ApiError('Cannot call API: {}'.format(response_52.status_code))

    return response_52
print(response_52)
# Out:
# [['ESTAB', 'NAICS2012', 'zipcode'], ['13', '52', '01001'], ['28', '52', '01002'], ['1', '52', '01003'], ['1', '52', '01004'], ['5', '52', '01005'], ['8', '52', '01007'], ['1', '52', '01009'], ['1', '52', '01010'], ['19', '52', '01013'], ['27', '52', '01020'], ['1', '52', '01021'], ['10', '52', '01027'], ['41', '52', '01028'], ['11', '52', '01030'], ['4', '52', '01033'], ['14', '52', '01035'], ['4', '52', '01036'], ['1', '52', '01039'], ['50', '52', '01040'], ['1', '52', '01050'], ['1', '52', '01053'], ['20', '52', '01056'], ['4', '52', '01057'], ['36', '52', '01060'], ['1', '52', '01061'], ['7', '52', '01062'], ['9', '52', '01069'], ['3', '52', '01073'], ['22', '52', '01075'], ['8', '52', '01077'], ['3', '52', '01080'], ['11', '52', '01082'], ['2', '52', '01083'], ['37', '52', '01085'], ['1', '52', '01088'], ['52', '52', '01089'], ['2', '52', '01090'], ['1', '52', '01092'], ['22', '52', '01095'], ['2', '52', '01096'], ['1', '52', '01098'], ['2', '52', '01102'], ['38', '52', '01103'],
# ...

# %%
with open('data52.txt', 'w') as outfile:
     json.dump(response_52, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

import pandas as pd

empl_df_52= pd.read_json('data52.txt', orient='records')
pd.read_json('data52.txt', orient='records')
empl_df_52.columns = empl_df_52.iloc[0]
empl_df_52.reindex(empl_df_52.index.drop(0))
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1        13        52   01001
# 2        28        52   01002
# 3         1        52   01003
# 4         1        52   01004
# 5         5        52   01005
# 6         8        52   01007
# 7         1        52   01009
# 8         1        52   01010
# 9        19        52   01013
# 10       27        52   01020
# 11        1        52   01021
# 12       10        52   01027
# 13       41        52   01028
# 14       11        52   01030
# 15        4        52   01033
# 16       14        52   01035
# 17        4        52   01036
# 18        1        52   01039
# 19       50        52   01040
# 20        1        52   01050
# 21        1        52   01053
# 22       20        52   01056
# 23        4        52   01057
# 24       36        52   01060
# 25        1        52   01061
# 26        7        52   01062
# 27        9        52   01069
# 28        3        52   01073
# 29       22        52   01075
# 30        8        52   01077
# ...

# %%
url = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=54&key=d78cecd59efe40449efbea033ae5a136a0226ad0"    
response_54 = req.get(url).json()

@rate_limited(5)
def call_api(self, url):
    response_54= req.get(url).json()

    if response_54.status_code != 200:
        raise ApiError('Cannot call API: {}'.format(response_54.status_code))

    return response_54
print(response_54)
# Out:
# [['ESTAB', 'NAICS2012', 'zipcode'], ['42', '54', '01001'], ['89', '54', '01002'], ['1', '54', '01003'], ['1', '54', '01004'], ['12', '54', '01005'], ['21', '54', '01007'], ['2', '54', '01008'], ['1', '54', '01009'], ['7', '54', '01010'], ['1', '54', '01012'], ['15', '54', '01013'], ['22', '54', '01020'], ['4', '54', '01022'], ['2', '54', '01026'], ['38', '54', '01027'], ['48', '54', '01028'], ['1', '54', '01029'], ['17', '54', '01030'], ['1', '54', '01032'], ['7', '54', '01033'], ['3', '54', '01034'], ['29', '54', '01035'], ['6', '54', '01036'], ['2', '54', '01037'], ['2', '54', '01038'], ['2', '54', '01039'], ['62', '54', '01040'], ['1', '54', '01041'], ['2', '54', '01053'], ['7', '54', '01054'], ['22', '54', '01056'], ['8', '54', '01057'], ['105', '54', '01060'], ['5', '54', '01061'], ['15', '54', '01062'], ['1', '54', '01066'], ['3', '54', '01068'], ['18', '54', '01069'], ['5', '54', '01072'], ['11', '54', '01073'], ['22', '54', '01075'], ['11', '54', '01077'], ['1', '54', '01079'
# ...

# %%
with open('data54.txt', 'w') as outfile:
     json.dump(response_54, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

import pandas as pd

empl_df_54= pd.read_json('data54.txt', orient='records')
pd.read_json('data54.txt', orient='records')
empl_df_54.columns = empl_df_54.iloc[0]
empl_df_54.reindex(empl_df_54.index.drop(0))
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1        42        54   01001
# 2        89        54   01002
# 3         1        54   01003
# 4         1        54   01004
# 5        12        54   01005
# 6        21        54   01007
# 7         2        54   01008
# 8         1        54   01009
# 9         7        54   01010
# 10        1        54   01012
# 11       15        54   01013
# 12       22        54   01020
# 13        4        54   01022
# 14        2        54   01026
# 15       38        54   01027
# 16       48        54   01028
# 17        1        54   01029
# 18       17        54   01030
# 19        1        54   01032
# 20        7        54   01033
# 21        3        54   01034
# 22       29        54   01035
# 23        6        54   01036
# 24        2        54   01037
# 25        2        54   01038
# 26        2        54   01039
# 27       62        54   01040
# 28        1        54   01041
# 29        2        54   01053
# 30        7        54   01054
# ...

# %%
url = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=61&key=d78cecd59efe40449efbea033ae5a136a0226ad0"    
response_61 = req.get(url).json()

@rate_limited(5)
def call_api(self, url):
    response_61= req.get(url).json()

    if response_61.status_code != 200:
        raise ApiError('Cannot call API: {}'.format(response_61.status_code))

    return response_61
print(response_61)
# Out:
# [['ESTAB', 'NAICS2012', 'zipcode'], ['3', '61', '01001'], ['33', '61', '01002'], ['1', '61', '01004'], ['2', '61', '01005'], ['9', '61', '01007'], ['4', '61', '01013'], ['7', '61', '01020'], ['6', '61', '01022'], ['3', '61', '01026'], ['9', '61', '01027'], ['9', '61', '01028'], ['1', '61', '01030'], ['2', '61', '01031'], ['2', '61', '01033'], ['7', '61', '01035'], ['1', '61', '01036'], ['2', '61', '01037'], ['2', '61', '01039'], ['23', '61', '01040'], ['1', '61', '01054'], ['7', '61', '01056'], ['2', '61', '01057'], ['22', '61', '01060'], ['6', '61', '01062'], ['1', '61', '01063'], ['7', '61', '01069'], ['1', '61', '01070'], ['1', '61', '01072'], ['1', '61', '01073'], ['8', '61', '01075'], ['1', '61', '01077'], ['2', '61', '01080'], ['2', '61', '01082'], ['1', '61', '01083'], ['9', '61', '01085'], ['14', '61', '01089'], ['7', '61', '01095'], ['2', '61', '01096'], ['2', '61', '01098'], ['9', '61', '01103'], ['8', '61', '01104'], ['5', '61', '01105'], ['8', '61', '01106'], ['1', '61', 
# ...

# %%
with open('data61.txt', 'w') as outfile:
     json.dump(response_61, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

import pandas as pd

empl_df_61= pd.read_json('data61.txt', orient='records')
pd.read_json('data61.txt', orient='records')
empl_df_61.columns = empl_df_61.iloc[0]
empl_df_61.reindex(empl_df_61.index.drop(0))
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1         3        61   01001
# 2        33        61   01002
# 3         1        61   01004
# 4         2        61   01005
# 5         9        61   01007
# 6         4        61   01013
# 7         7        61   01020
# 8         6        61   01022
# 9         3        61   01026
# 10        9        61   01027
# 11        9        61   01028
# 12        1        61   01030
# 13        2        61   01031
# 14        2        61   01033
# 15        7        61   01035
# 16        1        61   01036
# 17        2        61   01037
# 18        2        61   01039
# 19       23        61   01040
# 20        1        61   01054
# 21        7        61   01056
# 22        2        61   01057
# 23       22        61   01060
# 24        6        61   01062
# 25        1        61   01063
# 26        7        61   01069
# 27        1        61   01070
# 28        1        61   01072
# 29        1        61   01073
# 30        8        61   01075
# ...

# %%
url = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=62&key=d78cecd59efe40449efbea033ae5a136a0226ad0"    
response_62 = req.get(url).json()

@rate_limited(5)
def call_api(self, url):
    response_62= req.get(url).json()

    if response_62.status_code != 200:
        raise ApiError('Cannot call API: {}'.format(response_62.status_code))

    return response_62
print(response_62)
# Out:
# [['ESTAB', 'NAICS2012', 'zipcode'], ['46', '62', '01001'], ['78', '62', '01002'], ['3', '62', '01003'], ['1', '62', '01004'], ['7', '62', '01005'], ['30', '62', '01007'], ['1', '62', '01008'], ['2', '62', '01010'], ['3', '62', '01012'], ['28', '62', '01013'], ['52', '62', '01020'], ['1', '62', '01021'], ['2', '62', '01022'], ['1', '62', '01026'], ['40', '62', '01027'], ['66', '62', '01028'], ['19', '62', '01030'], ['1', '62', '01031'], ['2', '62', '01032'], ['5', '62', '01033'], ['1', '62', '01034'], ['31', '62', '01035'], ['7', '62', '01036'], ['5', '62', '01038'], ['2', '62', '01039'], ['143', '62', '01040'], ['2', '62', '01041'], ['4', '62', '01050'], ['9', '62', '01053'], ['2', '62', '01054'], ['32', '62', '01056'], ['6', '62', '01057'], ['2', '62', '01059'], ['125', '62', '01060'], ['2', '62', '01061'], ['40', '62', '01062'], ['1', '62', '01068'], ['22', '62', '01069'], ['1', '62', '01071'], ['7', '62', '01073'], ['31', '62', '01075'], ['13', '62', '01077'], ['4', '62', '01080']
# ...

# %%
with open('data62.txt', 'w') as outfile:
     json.dump(response_62, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

import pandas as pd

empl_df_62= pd.read_json('data62.txt', orient='records')
pd.read_json('data62.txt', orient='records')
empl_df_62.columns = empl_df_62.iloc[0]
empl_df_62.reindex(empl_df_62.index.drop(0))
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1        46        62   01001
# 2        78        62   01002
# 3         3        62   01003
# 4         1        62   01004
# 5         7        62   01005
# 6        30        62   01007
# 7         1        62   01008
# 8         2        62   01010
# 9         3        62   01012
# 10       28        62   01013
# 11       52        62   01020
# 12        1        62   01021
# 13        2        62   01022
# 14        1        62   01026
# 15       40        62   01027
# 16       66        62   01028
# 17       19        62   01030
# 18        1        62   01031
# 19        2        62   01032
# 20        5        62   01033
# 21        1        62   01034
# 22       31        62   01035
# 23        7        62   01036
# 24        5        62   01038
# 25        2        62   01039
# 26      143        62   01040
# 27        2        62   01041
# 28        4        62   01050
# 29        9        62   01053
# 30        2        62   01054
# ...

# %%
url = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=71&key=d78cecd59efe40449efbea033ae5a136a0226ad0"    
response_71 = req.get(url).json()

@rate_limited(5)
def call_api(self, url):
    response_71= req.get(url).json()

    if response_71.status_code != 200:
        raise ApiError('Cannot call API: {}'.format(response_71.status_code))

    return response_71
print(response_71)
# Out:
# [['ESTAB', 'NAICS2012', 'zipcode'], ['3', '71', '01001'], ['15', '71', '01002'], ['3', '71', '01007'], ['2', '71', '01008'], ['2', '71', '01010'], ['1', '71', '01011'], ['2', '71', '01013'], ['7', '71', '01020'], ['1', '71', '01026'], ['5', '71', '01027'], ['7', '71', '01028'], ['7', '71', '01030'], ['1', '71', '01031'], ['1', '71', '01032'], ['1', '71', '01033'], ['7', '71', '01035'], ['1', '71', '01036'], ['2', '71', '01038'], ['1', '71', '01039'], ['13', '71', '01040'], ['2', '71', '01041'], ['2', '71', '01053'], ['1', '71', '01054'], ['6', '71', '01056'], ['2', '71', '01057'], ['15', '71', '01060'], ['3', '71', '01062'], ['1', '71', '01063'], ['1', '71', '01068'], ['5', '71', '01069'], ['1', '71', '01070'], ['2', '71', '01072'], ['5', '71', '01073'], ['4', '71', '01075'], ['11', '71', '01077'], ['3', '71', '01082'], ['13', '71', '01085'], ['1', '71', '01086'], ['1', '71', '01088'], ['14', '71', '01089'], ['5', '71', '01095'], ['3', '71', '01098'], ['4', '71', '01103'], ['2', '71'
# ...

# %%
with open('data71.txt', 'w') as outfile:
     json.dump(response_71, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

import pandas as pd

empl_df_71= pd.read_json('data71.txt', orient='records')
pd.read_json('data71.txt', orient='records')
empl_df_71.columns = empl_df_71.iloc[0]
empl_df_71.reindex(empl_df_71.index.drop(0))
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1         3        71   01001
# 2        15        71   01002
# 3         3        71   01007
# 4         2        71   01008
# 5         2        71   01010
# 6         1        71   01011
# 7         2        71   01013
# 8         7        71   01020
# 9         1        71   01026
# 10        5        71   01027
# 11        7        71   01028
# 12        7        71   01030
# 13        1        71   01031
# 14        1        71   01032
# 15        1        71   01033
# 16        7        71   01035
# 17        1        71   01036
# 18        2        71   01038
# 19        1        71   01039
# 20       13        71   01040
# 21        2        71   01041
# 22        2        71   01053
# 23        1        71   01054
# 24        6        71   01056
# 25        2        71   01057
# 26       15        71   01060
# 27        3        71   01062
# 28        1        71   01063
# 29        1        71   01068
# 30        5        71   01069
# ...

# %%
url = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=23&key=d78cecd59efe40449efbea033ae5a136a0226ad0"    
response_23 = req.get(url).json()

@rate_limited(5)
def call_api(self, url):
    response_23= req.get(url).json()

    if response_23.status_code != 200:
        raise ApiError('Cannot call API: {}'.format(response_23.status_code))

    return response_23
print(response_23)
# Out:
# [['ESTAB', 'NAICS2012', 'zipcode'], ['55', '23', '01001'], ['27', '23', '01002'], ['1', '23', '01004'], ['14', '23', '01005'], ['30', '23', '01007'], ['5', '23', '01008'], ['3', '23', '01009'], ['20', '23', '01010'], ['3', '23', '01011'], ['1', '23', '01012'], ['28', '23', '01013'], ['62', '23', '01020'], ['1', '23', '01021'], ['2', '23', '01022'], ['1', '23', '01026'], ['56', '23', '01027'], ['56', '23', '01028'], ['1', '23', '01029'], ['31', '23', '01030'], ['5', '23', '01032'], ['33', '23', '01033'], ['9', '23', '01034'], ['23', '23', '01035'], ['31', '23', '01036'], ['6', '23', '01037'], ['20', '23', '01038'], ['8', '23', '01039'], ['46', '23', '01040'], ['2', '23', '01041'], ['8', '23', '01050'], ['2', '23', '01053'], ['7', '23', '01054'], ['83', '23', '01056'], ['34', '23', '01057'], ['29', '23', '01060'], ['2', '23', '01061'], ['17', '23', '01062'], ['1', '23', '01066'], ['11', '23', '01068'], ['34', '23', '01069'], ['6', '23', '01071'], ['6', '23', '01072'], ['30', '23', '010
# ...

# %%
with open('data23.txt', 'w') as outfile:
    json.dump(response_23, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

import pandas as pd

empl_df_23= pd.read_json('data23.txt', orient='records')
pd.read_json('data23.txt', orient='records')
empl_df_23.columns = empl_df_23.iloc[0]
empl_df_23.reindex(empl_df_23.index.drop(0))
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1        55        23   01001
# 2        27        23   01002
# 3         1        23   01004
# 4        14        23   01005
# 5        30        23   01007
# 6         5        23   01008
# 7         3        23   01009
# 8        20        23   01010
# 9         3        23   01011
# 10        1        23   01012
# 11       28        23   01013
# 12       62        23   01020
# 13        1        23   01021
# 14        2        23   01022
# 15        1        23   01026
# 16       56        23   01027
# 17       56        23   01028
# 18        1        23   01029
# 19       31        23   01030
# 20        5        23   01032
# 21       33        23   01033
# 22        9        23   01034
# 23       23        23   01035
# 24       31        23   01036
# 25        6        23   01037
# 26       20        23   01038
# 27        8        23   01039
# 28       46        23   01040
# 29        2        23   01041
# 30        8        23   01050
# ...

# %%
url = "https://api.census.gov/data/2015/zbp?get=ESTAB&for=ZIPCODE:*&NAICS2012=21&key=d78cecd59efe40449efbea033ae5a136a0226ad0"    
response_21 = req.get(url).json()

@rate_limited(5)
def call_api(self, url):
    response_21= req.get(url).json()

    if response_21.status_code != 200:
        raise ApiError('Cannot call API: {}'.format(response_21.status_code))

    return response_21
print(response_21)
# Out:
# [['ESTAB', 'NAICS2012', 'zipcode'], ['1', '21', '01002'], ['1', '21', '01020'], ['1', '21', '01026'], ['1', '21', '01032'], ['1', '21', '01033'], ['1', '21', '01050'], ['1', '21', '01062'], ['1', '21', '01075'], ['2', '21', '01085'], ['1', '21', '01201'], ['2', '21', '01226'], ['1', '21', '01238'], ['1', '21', '01257'], ['1', '21', '01262'], ['1', '21', '01266'], ['1', '21', '01342'], ['1', '21', '01375'], ['1', '21', '01438'], ['1', '21', '01503'], ['1', '21', '01504'], ['1', '21', '01516'], ['1', '21', '01522'], ['1', '21', '01523'], ['1', '21', '01540'], ['1', '21', '01564'], ['1', '21', '01571'], ['1', '21', '01583'], ['1', '21', '01843'], ['1', '21', '01864'], ['1', '21', '01867'], ['2', '21', '01887'], ['1', '21', '01907'], ['1', '21', '01930'], ['1', '21', '02021'], ['1', '21', '02026'], ['1', '21', '02030'], ['1', '21', '02038'], ['1', '21', '02043'], ['2', '21', '02081'], ['1', '21', '02093'], ['1', '21', '02132'], ['1', '21', '02138'], ['1', '21', '02148'], ['3', '21', '021
# ...

# %%
with open('data21.txt', 'w') as outfile:
    json.dump(response_21, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

import pandas as pd

empl_df_21= pd.read_json('data21.txt', orient='records')
pd.read_json('data21.txt', orient='records')
empl_df_21.columns = empl_df_21.iloc[0]
empl_df_21.reindex(empl_df_21.index.drop(0))
# Out:
# 0    ESTAB NAICS2012 zipcode
# 1        1        21   01002
# 2        1        21   01020
# 3        1        21   01026
# 4        1        21   01032
# 5        1        21   01033
# 6        1        21   01050
# 7        1        21   01062
# 8        1        21   01075
# 9        2        21   01085
# 10       1        21   01201
# 11       2        21   01226
# 12       1        21   01238
# 13       1        21   01257
# 14       1        21   01262
# 15       1        21   01266
# 16       1        21   01342
# 17       1        21   01375
# 18       1        21   01438
# 19       1        21   01503
# 20       1        21   01504
# 21       1        21   01516
# 22       1        21   01522
# 23       1        21   01523
# 24       1        21   01540
# 25       1        21   01564
# 26       1        21   01571
# 27       1        21   01583
# 28       1        21   01843
# 29       1        21   01864
# 30       1        21   01867
# ...    ...       ...     ...
# ...

# %%
concat = pd.concat([empl_df_11,empl_df_21, empl_df_51, empl_df_52, empl_df_61, empl_df_62, empl_df_71])
# concat.columns = concat.iloc[0]
concat.reindex(concat.index.drop(0))
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-120-33407804f30c> in <module>()
#       1 concat = pd.concat([empl_df_11,empl_df_21, empl_df_51, empl_df_52, empl_df_61, empl_df_62, empl_df_71])
#       2 # concat.columns = concat.iloc[0]
# ----> 3 concat.reindex(concat.index.drop(0))
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3617         """
#    3618         labels = com._index_labels_to_array(labels)
# -> 3619         indexer = self.get_indexer(labels)
#    3620         mask = indexer == -1
#    3621         if mask.any():
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2581
#    2582         if not self.is_unique:
# -> 2583             raise InvalidIndexError('Reindexing only valid with uniquely'
# ...

# %%
concat.drop([0])
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1         1        11   01005
# 2         1        11   01007
# 3         1        11   01010
# 4         1        11   01030
# 5         1        11   01033
# 6         1        11   01034
# 7         1        11   01036
# 8         1        11   01038
# 9         1        11   01057
# 10        1        11   01059
# 11        1        11   01062
# 12        1        11   01069
# 13        1        11   01071
# 14        3        11   01077
# 15        1        11   01081
# 16        1        11   01082
# 17        1        11   01095
# 18        1        11   01201
# 19        1        11   01220
# 20        1        11   01230
# 21        1        11   01237
# 22        1        11   01243
# 23        1        11   01254
# 24        1        11   01255
# 25        2        11   01262
# 26        1        11   01267
# 27        1        11   01355
# 28        2        11   01360
# 29        1        11   01364
# 30        1        11   01366
# ...

# %%
concat.reset_index()
concat.drop([0])

# concat.columns = concat.iloc[0]
# concat.reindex(concat.index.drop(0))
# Out:
# 0     ESTAB NAICS2012 zipcode
# 1         1        11   01005
# 2         1        11   01007
# 3         1        11   01010
# 4         1        11   01030
# 5         1        11   01033
# 6         1        11   01034
# 7         1        11   01036
# 8         1        11   01038
# 9         1        11   01057
# 10        1        11   01059
# 11        1        11   01062
# 12        1        11   01069
# 13        1        11   01071
# 14        3        11   01077
# 15        1        11   01081
# 16        1        11   01082
# 17        1        11   01095
# 18        1        11   01201
# 19        1        11   01220
# 20        1        11   01230
# 21        1        11   01237
# 22        1        11   01243
# 23        1        11   01254
# 24        1        11   01255
# 25        2        11   01262
# 26        1        11   01267
# 27        1        11   01355
# 28        2        11   01360
# 29        1        11   01364
# 30        1        11   01366
# ...
